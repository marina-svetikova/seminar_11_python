# %%
#Дана функция f(x) = sin(x)^2 - cos(x)^2

#1.Определить корни (найти такие х, при которых f(x) = 0) - корни уравнения f(x) = 0

#2.Найти интервалы, на которых функция возрастает (решить неравенства где производная больше или меньше нуля)

#3.Найти интервалы, на которых функция убывает

#4.Построить график

#5.Вычислить вершину (найти производню и приравнять к нулю)

#6.Определить промежутки, на котором f > 0 (Найти такие x, при которых f(х) > 0) неравенствo f(x) > 0

#7.Определить промежутки, на котором f < 0 ( Найти такие x, при которых f(х) < 0) неравенствo f(x) < 0

# %%
from sympy.plotting import plot #  в библиотеке симпай есть класс плоттинг
from sympy import Symbol, solve, diff, solveset, S, pprint, solveset, sin, cos 
#4. Постороить график
x = Symbol('x')
f = sin(x)**2 - cos(x)**2 
plot(f)

# %%
#1.Определить корни 
ans = solve(f,x) 
print (ans)
for i in ans:
    print(i.evalf())
# Out:
# [-pi/4, pi/4]
# -0.785398163397448
# 0.785398163397448

# %%
#6.Определить промежутки, на котором f > 0 (Найти такие x, при которых f(х) > 0) неравенствo f(x) > 0
#solveset - получить корни в определенном множестве

#pprint (solveset(f > 0, x, domain=S.Reals), use_unicode=True) 
solve(f > 0,x)
# Out:
# (pi/4 < x) & (x < 3*pi/4)

# %%
#7.Определить промежутки, на котором f < 0 ( Найти такие x, при которых f(х) < 0) неравенствo f(x) < 0

#pprint(solveset(f < 0, x, domain=S.Reals), use_unicode=True)
solve(f < 0,x)
# Out:
# ((0 <= x) & (x < pi/4)) | ((x < pi) & (3*pi/4 < x))

# %%
#5.Вычислить вершину (найти производню и приравнять к нулю)

diff_f = diff(f,x)
print(diff_f)
solve(diff_f,x)
# Out:
# 4*sin(x)*cos(x)
# [0, pi/2, pi, 3*pi/2]

# %%
#2.Найти интервалы, на которых функция возрастает (решить неравенства где производная больше или меньше нуля)

pprint(solveset(diff_f > 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛   π⎞
# ⎜0, ─⎟
# ⎝   2⎠

# %%
#3.Найти интервалы, на которых функция убывает

pprint(solveset(diff_f < 0, x, domain=S.Reals), use_unicode=True)
# Out:
# ⎛π   ⎞
# ⎜─, π⎟
# ⎝2   ⎠
